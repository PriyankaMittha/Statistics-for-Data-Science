# %% [markdown]
# # Measure of Disperssion

# %%
ages_lst = [23,43,23,56,74,67,98,44,32]

# %%
import numpy as np

# %%
np.mean(ages_lst)
# Out:
# 51.111111111111114

# %%
np.var(ages_lst)
# Out:
# 562.320987654321

# %%
np.std(ages_lst)
# Out:
# 23.713308239347818

# %%
import seaborn as sns

# %%
sns.histplot(ages_lst, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
data = [[10,12,13], [34,23,45], [32,34,21]]

# %%
data
# Out:
# [[10, 12, 13], [34, 23, 45], [32, 34, 21]]

# %%
df = pd.DataFrame(data, columns = ['A','B','C'])

# %%
df.head()
# Out:
#     A   B   C
# 0  10  12  13
# 1  34  23  45
# 2  32  34  21

# %%
df.var()
# Out:
# A    177.333333
# B    121.000000
# C    277.333333
# dtype: float64

# %%
df.var(axis=1)
# Out:
# 0      2.333333
# 1    121.000000
# 2     49.000000
# dtype: float64

# %%
df.var(axis=1)
# Out:
# 0      2.333333
# 1    121.000000
# 2     49.000000
# dtype: float64
